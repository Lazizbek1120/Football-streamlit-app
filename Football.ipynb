# %%
import streamlit as st
import pandas as pd
import matplotlib as plt

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Football.csv")

st.set_page_config(page_title="Futbol Analiz", layout="wide")

st.title(" La Liga Player Statistikasi")




st.sidebar.header("Filter")

year = st.sidebar.selectbox("Yil tanlang", df["Year"].unique())
league = st.sidebar.selectbox("Liga tanlang", df["League"].unique())
club = st.sidebar.selectbox("Klub tanlang", df["Club"].unique())

filtered_df = df[
    (df["Year"] == year) &
    (df["League"] == league) &
    (df["Club"] == club)
]

st.subheader("O'yinchilar ro'yxati")
st.dataframe(filtered_df)

# Eng kop gol urgan oyinchilar
st.subheader("Top 10 Eng Ko'p Gol")

top_players = filtered_df.sort_values(by="Goals", ascending=False).head(10)

plt.figure()
plt.bar(top_players["Player Names"], top_players["Goals"])
plt.xticks(rotation=45)
st.pyplot(plt)
# Out:
# 2026-02-08 18:18:45.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:45.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:46.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:46.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-08 18:18:46.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
